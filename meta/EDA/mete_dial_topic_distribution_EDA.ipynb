# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-03-07%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.59.08.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-03-07%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%202.59.08.png)

# %%
import os 
import pandas as pd 
import numpy as np

# %%
directory = os.getenv('HOME') + '/aiffel/aiffelthon/'

# %%
df = pd.read_csv(directory + 'meta_eng_raw_0306_v1.csv')
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#                                     text  \
# 0                          생각이 쪼금씩 바뀌더라고
# 1                어 알겠는가 외국인들이 그래도 잘 적응하고
# 2               아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3  보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                    dial  \
# 0                         생각이 쪼금씩 바뀌드라고
# 1               어 알겄는가 외국인들이 그래도 잘 적응하고
# 2             아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3  보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                                  eng  \
# 0                 I've changed my mind a little bit.
# 1    You know what? Foreigners still get used to it.
# 2  All of a sudden, I think I've ripped off my ap...
# 3  I have a lot of ideas about getting older in a...
# 4        It's a little bit of a tastey, but still...
#
#                         title creator distributor    year  \
# 0                DJSX20003625    솔트룩스        솔트룩스  2020.0
# ...

# %%
df2 = df.copy()

# %%
df = df.drop(['annotation_level','title','creator','distributor','year','sampling','author','publisher','date','prin_res','curr_res','age2','sex2','prin_res2','curr_res2'],axis=1)

# %%
df.head()
# Out:
#                                     text  \
# 0                          생각이 쪼금씩 바뀌더라고
# 1                어 알겠는가 외국인들이 그래도 잘 적응하고
# 2               아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3  보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                    dial  \
# 0                         생각이 쪼금씩 바뀌드라고
# 1               어 알겄는가 외국인들이 그래도 잘 적응하고
# 2             아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3  보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                                  eng              category  \
# 0                 I've changed my mind a little bit.  전라방언 > 사적 대화 > 일상 대화
# 1    You know what? Foreigners still get used to it.    전라방언 > 사적대화 > 일상대화
# 2  All of a sudden, I think I've ripped off my ap...  전라방언 > 사적 대화 > 일상 대화
# 3  I have a lot of ideas about getting older in a...  전라방언 > 사적 대화 > 일상 대화
# 4        It's a little bit of a tastey, but still...  전라방언 > 사적 대화 > 일상 대화
#
# ...

# %%
df
# Out:
#                                                      text  \
# 0                                           생각이 쪼금씩 바뀌더라고
# 1                                 어 알겠는가 외국인들이 그래도 잘 적응하고
# 2                                아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3                   보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                            약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...                                                   ...
# 949883  뭐~ 맨날 집에서 인제 음식도 그냥 가까운 데 나가서 먹는 게 아니라 되게 시켜먹는...
# 949884                  너는 만약에 그런 시대가 오면 네가 어떻게 활동할 것 같애?
# 949885      하이브도 있고 #조석 작가 이제 조의 영역이라는 웹툰도 있고 마음의 소리도 있는데
# 949886        추석도 친척들도 사촌까지만 모이긴 했는데 이~ 다 모이니까 할 말도 많고 이~
# 949887             커피숍 가서 이렇게 먹고 하는 거가 훨씬 맛있거든 기분상으로도 그렇고
#
#                                                      dial  \
# 0                                           생각이 쪼금씩 바뀌드라고
# 1                                 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                               아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# ...

# %%
df.isnull().sum()
# Out:
# text             0
# dial             0
# eng              0
# category       182
# topic            0
# age              0
# sex              0
# stdn             0
# eojeol_stdn      0
# reg              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# text           0
# dial           0
# eng            0
# category       0
# topic          0
# age            0
# sex            0
# stdn           0
# eojeol_stdn    0
# reg            0
# dtype: int64

# %%
df.duplicated(subset='text').sum()
# Out:
# 7617

# %%
df.duplicated(subset='eng').sum()
# Out:
# 64555

# %%
df.duplicated(subset='stdn').sum()
# Out:
# 8095

# %%
df.drop_duplicates(subset="text", inplace = True , ignore_index = True )

# %%
df.drop_duplicates(subset="eng", inplace = True , ignore_index = True )

# %%
df.drop_duplicates(subset="stdn", inplace = True , ignore_index = True )

# %%
df.duplicated(subset='text').sum()
# Out:
# 0

# %%
df.duplicated(subset='eng').sum()
# Out:
# 0

# %%
df.duplicated(subset='stdn').sum()
# Out:
# 0

# %%
df.topic.value_counts()
# Out:
# 가족            138400
# 연애/결혼          73508
# 먹거리            61605
# 회사/학교          59447
# 여행지(국내/해외)     42992
# 건강             39483
# 드라마            35923
# 성격             26443
# 취미             26041
# 방송/연예          21022
# 영화             20907
# 아르바이트          20784
# 꿈(목표)          20206
# 반려동물           18681
# 계절             17733
# 쇼핑             17380
# 음악             16533
# 다이어트           15267
# 스타일            13943
# 스포츠/레저         13072
# 경제             12125
# 선물             11966
# 군대             11443
# 공연             11422
# 재테크            11245
# 날씨             11201
# 게임             10625
# 문학             10489
# 역사             10436
# 종교             10354
# 좌우명            10322
# 전자기기           10255
# 자동차/오토바이        9767
# 자격증             8243
# 콤플렉스            8135
# 만화              6910
# SNS             5966
# 정치              3593
# 4차산업혁명          3130
# 법률              2488
# Name: topic, dtype: int64

# %%
sum_top = df.topic.value_counts()[:7]
sum_top
# Out:
# 가족            138400
# 연애/결혼          73508
# 먹거리            61605
# 회사/학교          59447
# 여행지(국내/해외)     42992
# 건강             39483
# 드라마            35923
# Name: topic, dtype: int64

# %%
sum = df.topic.value_counts().sum()
sum
# Out:
# 879485

# %%
avg = df.topic.value_counts() / sum
avg
# Out:
# 가족            0.157365
# 연애/결혼         0.083581
# 먹거리           0.070047
# 회사/학교         0.067593
# 여행지(국내/해외)    0.048883
# 건강            0.044893
# 드라마           0.040845
# 성격            0.030066
# 취미            0.029609
# 방송/연예         0.023903
# 영화            0.023772
# 아르바이트         0.023632
# 꿈(목표)         0.022975
# 반려동물          0.021241
# 계절            0.020163
# 쇼핑            0.019762
# 음악            0.018799
# 다이어트          0.017359
# 스타일           0.015854
# 스포츠/레저        0.014863
# 경제            0.013786
# 선물            0.013606
# 군대            0.013011
# 공연            0.012987
# 재테크           0.012786
# 날씨            0.012736
# 게임            0.012081
# 문학            0.011926
# 역사            0.011866
# 종교            0.011773
# 좌우명           0.011736
# 전자기기          0.011660
# 자동차/오토바이      0.011105
# 자격증           0.009373
# 콤플렉스          0.009250
# 만화            0.007857
# SNS           0.006784
# 정치            0.004085
# 4차산업혁명        0.003559
# 법률            0.002829
# ...

# %%
avg_10 = avg[:10]
avg_10
# Out:
# 가족            0.157365
# 연애/결혼         0.083581
# 먹거리           0.070047
# 회사/학교         0.067593
# 여행지(국내/해외)    0.048883
# 건강            0.044893
# 드라마           0.040845
# 성격            0.030066
# 취미            0.029609
# 방송/연예         0.023903
# Name: topic, dtype: float64

# %% [markdown]
# ####  - 전체 데이터에서 topic의 비율을 상위 10개만 추출해보았다.

# %% [markdown]
# ### 5개의 데이터 셋에 대한 topic 분포 비율
# - 한글 폰트 지원이 계속 안된다 ;;;

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# %%
# 맥 한글 폰트 깨짐 현상 발생 
# 이 코드로 했을때는 해결이 안되네용
# rc('font', family='AppleGothic') 
# plt.rcParams['axes.unicode_minus'] = False

# %%
# 이 코드 사용하니까 해결 
import matplotlib as mpl
plt.rcParams['font.family'] = 'NanumBarunGothic'
mpl.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(9,5))

plt.title('topic_distribution' , fontsize=15)

plt.ylabel('Counts' , fontsize=12)
plt.xlabel('topic' , fontsize=12)


x = df['topic'].value_counts().plot.bar()

# %%
# 3만 이상만 추출
plt.figure(figsize=(9,5))

plt.title('topic_distribution' , fontsize=15)

plt.ylabel('Counts' , fontsize=12)
plt.xlabel('topic' , fontsize=12)
# ax.bar_label(bar, label_type ='center', color = 'white')

sum_top.plot.bar()
# Out:
# <AxesSubplot:title={'center':'topic_distribution'}, xlabel='topic', ylabel='Counts'>

# %%
# avg 상위 10개 추출
plt.figure(figsize=(9,5))

plt.title('topic_distribution' , fontsize=15)

plt.ylabel('avg' , fontsize=12)
plt.xlabel('topic' , fontsize=12)

avg_10.plot.bar()
# Out:
# <AxesSubplot:title={'center':'topic_distribution'}, xlabel='topic', ylabel='avg'>

# %% [markdown]
# ## 지역별로 나눠서 확인

# %%
df['reg'].value_counts()
# Out:
# kw    293322
# jj    192101
# jd    170924
# gs    112863
# cc    110275
# Name: reg, dtype: int64

# %%
df_jj = df[df['reg'] == 'jj']
df_kw = df[df['reg'] == 'kw']
df_jd = df[df['reg'] == 'jd']
df_gs = df[df['reg'] == 'gs']
df_cc = df[df['reg'] == 'cc']

# %%
# 결측치 5개 전부 확인 
df_gs.isnull().sum()
# Out:
# text           0
# dial           0
# eng            0
# category       0
# topic          0
# age            0
# sex            0
# stdn           0
# eojeol_stdn    0
# reg            0
# dtype: int64

# %%
# 중복값 5개 전부 확인
df_cc.duplicated().sum()
# Out:
# 0

# %%
df_jj.topic.value_counts(normalize = True)[:10]
# Out:
# 가족            0.190754
# 먹거리           0.123768
# 회사/학교         0.100026
# 여행지(국내/해외)    0.074586
# 건강            0.062915
# 취미            0.047954
# 연애/결혼         0.047329
# 역사            0.040349
# 방송/연예         0.027756
# 꿈(목표)         0.026210
# Name: topic, dtype: float64

# %%
df_kw.topic.value_counts(normalize = True)[:10]
# Out:
# 가족            0.285001
# 연애/결혼         0.160206
# 드라마           0.083986
# 회사/학교         0.083669
# 먹거리           0.038507
# 성격            0.026333
# 여행지(국내/해외)    0.024250
# 건강            0.023551
# 좌우명           0.023282
# 영화            0.022941
# Name: topic, dtype: float64

# %%
df_jd.topic.value_counts(normalize = True)[:10]
# Out:
# 먹거리           0.066322
# 여행지(국내/해외)    0.057897
# 건강            0.056739
# 연애/결혼         0.049051
# 가족            0.048601
# 회사/학교         0.046418
# 아르바이트         0.042691
# 다이어트          0.037145
# 계절            0.034460
# 성격            0.034273
# Name: topic, dtype: float64

# %%
df_gs.topic.value_counts(normalize = True)[:10]
# Out:
# 여행지(국내/해외)    0.055067
# 먹거리           0.052923
# 건강            0.052001
# 연애/결혼         0.038773
# 가족            0.038622
# 회사/학교         0.036761
# 반려동물          0.032455
# 성격            0.030435
# 아르바이트         0.030178
# 군대            0.029248
# Name: topic, dtype: float64

# %%
df_cc.topic.value_counts(normalize = True)[:10]
# Out:
# 먹거리           0.083655
# 성격            0.056813
# 가족            0.049812
# 여행지(국내/해외)    0.049331
# 건강            0.044634
# 연애/결혼         0.042294
# 스타일           0.040852
# 선물            0.035266
# 음악            0.035185
# 영화            0.033235
# Name: topic, dtype: float64

# %%
data = df.groupby('reg')['topic'].value_counts(normalize=True).unstack()
# regs = df.reg.unique()
# data.loc['cc'].sort_values(ascending=False).head(5)

plt.figure(figsize=(15,10))
for i,reg in enumerate(regs) :
    ax = plt.subplot(3,2,i+1)
    temp = data.loc[reg].sort_values(ascending=False).round(2).head(5)
    bar = ax.bar(temp.index, temp)
    ax.bar_label(bar, label_type ='center', color = 'white')
    plt.title(f"top_5 : {reg}")
    plt.xticks(rotation=45)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 먹거리 , 여행지(국내/해외) , 가족 3가지 topic이 5개 지역에 공통적으로 높은 비율을 차지한다

# %% [markdown]
# ## ref
# - https://steadiness-193.tistory.com/210
# - 맥 한글 폰트 깨짐 https://study-grow.tistory.com/entry/mac-os-matplotib-%EC%82%AC%EC%9A%A9%EC%8B%9C-font-%ED%95%9C%EA%B8%80-%ED%8F%B0%ED%8A%B8-%EA%B9%A8%EC%A7%90-%ED%98%84%EC%83%81-%ED%95%B4%EA%B2%B0%EB%B2%95
